# %%
from qiskit import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0fc105f133ef> in <module>()
# ----> 1 from qiskit import *
#
# ModuleNotFoundError: No module named 'qiskit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install qiskit
# Out:
# ...
#      |████████████████████████████████| 6.7MB 2.6MB/s
# ...
#      |████████████████████████████████| 23.3MB 90kB/s
# ...
#      |████████████████████████████████| 163kB 47.2MB/s
# ...
#      |████████████████████████████████| 184kB 47.1MB/s
# ...
#      |████████████████████████████████| 1.9MB 46.6MB/s
# ...
#      |████████████████████████████████| 5.8MB 42.8MB/s
# ...
#      |████████████████████████████████| 51kB 5.5MB/s
# ...
#      |████████████████████████████████| 962kB 38.7MB/s
# ...
#      |████████████████████████████████| 51kB 5.2MB/s
# ...
#      |████████████████████████████████| 296kB 43.0MB/s
# ...
#      |████████████████████████████████| 71kB 235kB/s
# ...
#      |████████████████████████████████| 26.0MB 1.6MB/s
# ...
#      |████████████████████████████████| 583kB 39.7MB/s
# ...
#      |████████████████████████████████| 2.7MB 42.1MB/s
# ...
#   Created wheel for qiskit: filename=qiskit-0.19.6-cp36-none-any.whl size=3019 sha256=be795f7ded7bf674de54111b8dce00d780fcb6368a943308c2c9fdd63a669941
# ...

# %%
from qiskit import *

# %%
qr=QuantumRegister(2)

# %%
cr= ClassicalRegister(2)

# %%
qc= QuantumCircuit(qr,cr)

# %%
# %matplotlib inline

# %%
qc.draw()
# Out:
#
# q0_0:
#
# q0_1:
#
# c0_0:
#
# c0_1:

# %%
qc.h(qr[0])

# %%
qc.draw(output='mpl')

# %%
qc.cx(qr[0],qr[1])

# %%
qc.draw(output='mpl')

# %%
qc.measure(qr,cr)

# %%
qc.draw(output='mpl')

# %%
simulator= Aer.get_backend('qasm_simulator')

# %%
result= execute(qc,backend= simulator).result()

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result.get_counts(qc))

# %%
from qiskit import IBMQ

# %%
IBMQ.save_account('4ec46ce4224cdffd7ee1eff787ce00030efd96490d8f5b7bc068aae91526cc00705ca9d13898992e04d97f62bf3a5b110aed86fb7ada253714cccb6c302ebeb6')

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider= IBMQ.get_provider('ibm-q')

# %%
qcomp= provider.get_backend('ibmq_london')

# %%
job = execute(qc, backend=qcomp)

# %%
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
result= job.result()

# %%
plot_histogram(result.get_counts(qc))

# %% [markdown]
# The above histogram is quite different from the simulating histogram because of the errors that normally show up . This simulation is perfect , Hope to attain same results as that of primary simulation with increase improvements in tech.

# %%
from google.colab import drive
drive.mount('/content/drive')
